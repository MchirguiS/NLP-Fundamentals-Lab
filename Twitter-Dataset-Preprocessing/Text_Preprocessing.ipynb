# %%
import pandas as pd

# %%
path = "/content/twitter_dataset.csv"

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Tweet_ID        Username  \
# 0         1         julie81
# 1         2   richardhester
# 2         3  williamsjoseph
# 3         4     danielsmary
# 4         5      carlwarren
#
#                                                 Text  Retweets  Likes  \
# 0  Party least receive say or single. Prevent pre...         2     25
# 1  Hotel still Congress may member staff. Media d...        35     29
# 2  Nice be her debate industry that year. Film wh...        51     25
# 3  Laugh explain situation career occur serious. ...        37     18
# 4  Involve sense former often approach government...        27     80
#
#              Timestamp
# 0  2023-01-30 11:00:51
# 1  2023-01-02 22:45:58
# 2  2023-01-18 11:25:19
# 3  2023-04-10 22:06:29
# 4  2023-01-24 07:12:21

# %%
df.shape
# Out:
# (10000, 6)

# %%
df = df.head(300)

# %%
df['Text'] = df['Text'].str.lower()

# %%
df.head(300)
# Out:
#      Tweet_ID            Username  \
# 0           1             julie81
# 1           2       richardhester
# 2           3      williamsjoseph
# 3           4         danielsmary
# 4           5          carlwarren
# ..        ...                 ...
# 295       296          phenderson
# 296       297               amy24
# 297       298             emedina
# 298       299       bergervanessa
# 299       300  barrettchristopher
#
#                                                   Text  Retweets  Likes  \
# 0    party least receive say or single. prevent pre...         2     25
# 1    hotel still congress may member staff. media d...        35     29
# 2    nice be her debate industry that year. film wh...        51     25
# 3    laugh explain situation career occur serious. ...        37     18
# 4    involve sense former often approach government...        27     80
# ..                                                 ...       ...    ...
# 295  community best evening evidence work who full ...        96     95
# 296  tell reveal director member sea game important...        90    100
# 297  peace none for prevent picture fire program in...        74     25
# 298  tv mouth sort. rest too southern a half school...        80      1
# 299  so never book station action value. try north ...        85     19
#
#                Timestamp
# 0    2023-01-30 11:00:51
# 1    2023-01-02 22:45:58
# 2    2023-01-18 11:25:19
# 3    2023-04-10 22:06:29
# 4    2023-01-24 07:12:21
# ..                   ...
# 295  2023-04-21 18:36:52
# 296  2023-04-10 23:24:13
# 297  2023-04-15 23:14:10
# 298  2023-02-22 03:12:55
# 299  2023-01-09 19:39:19
#
# [300 rows x 6 columns]

# %%
import string

def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

# %%
df['Text'] = df['Text'].apply(remove_punctuation)

# %%
df.head()
# Out:
#    Tweet_ID        Username  \
# 0         1         julie81
# 1         2   richardhester
# 2         3  williamsjoseph
# 3         4     danielsmary
# 4         5      carlwarren
#
#                                                 Text  Retweets  Likes  \
# 0  Party least receive say or single Prevent prev...         2     25
# 1  Hotel still Congress may member staff Media dr...        35     29
# 2  Nice be her debate industry that year Film whe...        51     25
# 3  Laugh explain situation career occur serious F...        37     18
# 4  Involve sense former often approach government...        27     80
#
#              Timestamp
# 0  2023-01-30 11:00:51
# 1  2023-01-02 22:45:58
# 2  2023-01-18 11:25:19
# 3  2023-04-10 22:06:29
# 4  2023-01-24 07:12:21

# %%
from textblob import TextBlob

def correct_spelling(text):
    return str(TextBlob(text).correct())

# %%
df['Text'] = df['Text'].apply(correct_spelling)

# %%
df.head()
# Out:
#    Tweet_ID        Username  \
# 0         1         julie81
# 1         2   richardhester
# 2         3  williamsjoseph
# 3         4     danielsmary
# 4         5      carlwarren
#
#                                                 Text  Retweets  Likes  \
# 0  Party least receive say or single Prevent prev...         2     25
# 1  Hotel still Congress may member staff Media dr...        35     29
# 2  Vice be her debate industry that year Film whe...        51     25
# 3  Laugh explain situation career occur serious G...        37     18
# 4  Involve sense former often approach government...        27     80
#
#              Timestamp
# 0  2023-01-30 11:00:51
# 1  2023-01-02 22:45:58
# 2  2023-01-18 11:25:19
# 3  2023-04-10 22:06:29
# 4  2023-01-24 07:12:21

# %%
from nltk.tokenize import word_tokenize

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['Text'] = df['Text'].apply(word_tokenize)

# %%
df
# Out:
#       Tweet_ID         Username  \
# 0            1          julie81
# 1            2    richardhester
# 2            3   williamsjoseph
# 3            4      danielsmary
# 4            5       carlwarren
# ...        ...              ...
# 9995      9996            ntate
# 9996      9997   garrisonjoshua
# 9997      9998  adriennejackson
# 9998      9999         kcarlson
# 9999     10000       vdickerson
#
#                                                    Text  Retweets  Likes  \
# 0     [Party, least, receive, say, or, single, Preve...         2     25
# 1     [Hotel, still, Congress, may, member, staff, M...        35     29
# 2     [Vice, be, her, debate, industry, that, year, ...        51     25
# 3     [Laugh, explain, situation, career, occur, ser...        37     18
# 4     [Involve, sense, former, often, approach, gove...        27     80
# ...                                                 ...       ...    ...
# 9995  [Agree, reflect, military, box, ability, ever,...        81     86
# 9996  [Worn, which, push, still, Degree, sometimes, ...        73    100
# 9997  [You, day, agent, likely, region, Teacher, dat...        10     62
# 9998  [Guess, without, successful, save, Articular, ...        21     60
# 9999  [Body, onto, understand, team, about, product,...        65     54
#
#                 Timestamp
# 0     2023-01-30 11:00:51
# 1     2023-01-02 22:45:58
# 2     2023-01-18 11:25:19
# 3     2023-04-10 22:06:29
# 4     2023-01-24 07:12:21
# ...                   ...
# 9995  2023-01-15 11:46:20
# 9996  2023-05-06 00:46:54
# 9997  2023-02-27 14:55:08
# 9998  2023-01-09 16:09:35
# 9999  2023-04-19 01:35:56
#
# [10000 rows x 6 columns]

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def remove_stopwords(words):
    return [word for word in words if word.lower() not in stop_words]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['Text'] = df['Text'].apply(remove_stopwords)

# %%
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()

def stem_words(words):
    return [stemmer.stem(word) for word in words]

# %%
df['Text'] = df['Text'].apply(stem_words)
